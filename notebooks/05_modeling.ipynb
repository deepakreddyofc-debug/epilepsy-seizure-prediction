# %%
from pathlib import Path
import numpy as np

processed_dir = Path("../data_processed")

feature_files = sorted(processed_dir.glob("*_features.npy"))
print("Found feature files:", [f.name for f in feature_files])

# load one file as a test
X = np.load(feature_files[0])
print("X shape =", X.shape)
# Out:
# Found feature files: ['chb01_01_features.npy', 'chb01_02_features.npy', 'chb01_03_features.npy', 'chb01_04_features.npy', 'chb01_05_features.npy', 'chb01_06_features.npy', 'chb01_07_features.npy', 'chb01_08_features.npy']
# X shape = (720, 69)
